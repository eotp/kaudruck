# %% [markdown]
# # Project _Kaudruck_ - Force correction model

# %% [markdown]
# ### Setup

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.cm as cmap
import numpy as np
from skimage import io
import pandas as pd

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['legend.fontsize'] = "large"

# %%
src_dir = os.path.abspath(os.path.join(os.pardir, 'src'))
sys.path.append(src_dir)

# %%
from kaudruck import KauDruck, plot_aoi_aor

# %% [markdown]
# ## Kugeldurchmesser 12.0 [mm]

# %%
d120 = pd.read_excel('../data/empirical/Serie1_12mmugel_17052019_Rohdaten.xlsx', 
                    skiprows=list(range(2))
                    )
d120
# Out:
#     F [N] ZWICK   F [N] Python  F[N] korrigiert-Python  Fläche [mm²] Python  \
# 0             2           0.11                    2.34                 0.00
# 1             5           5.62                    2.79                 0.09
# 2            10          16.12                    7.04                 0.23
# 3            20          29.84                   19.26                 0.40
# 4            30          37.71                   29.71                 0.48
# 5            40          45.16                   41.87                 0.57
# 6            50          50.00                   50.98                 0.62
# 7            60          54.64                   60.60                 0.67
# 8            70          61.36                   76.06                 0.75
# 9            80          66.40                   88.84                 0.80
# 10          100          72.61                  106.00                 0.86
#
#    Druck KORRIGIERT [MPa] Python  Druck [Mpa] Python  Gewicht/ Fläche Python  \
# 0                     1162,12 !!               56.63                   0.310
# 1                          31.56               63.54                   0.348
# 2                          30.56               69.99                   0.383
# 3                             48               74.33                   0.407
# 4                          61.52               78.10                   0.427
# 5                           72.9               78.62                   0.430
# 6                          82.54               80.95                   0.443
# 7                          90.45               81.56                   0.446
# 8                         101.62               81.99                   0.449
# 9                         110.39               82.51                   0.451
# 10                        122.66               84.03                   0.460
#
#     Farbgewicht Python  Fläche (Pixel)  Unnamed: 9  F[N] korrigiert-Python.1  \
# 0                    1               2         NaN                      2.34
# 1                   31              88         NaN                      2.79
# 2                   88             229         NaN                      7.04
# 3                  162             399         NaN                     19.26
# 4                  205             480         NaN                     29.71
# 5                  246             571         NaN                     41.87
# 6                  272             614         NaN                     50.98
# 7                  297             666         NaN                     60.60
# 8                  334             744         NaN                     76.06
# 9                  361             800         NaN                     88.84
# 10                 395             859         NaN                    106.00
#
#     Gewicht/ Fläche Python.1
# 0                      0.310
# 1                      0.348
# 2                      0.383
# 3                      0.407
# 4                      0.427
# 5                      0.430
# 6                      0.443
# 7                      0.446
# 8                      0.449
# 9                      0.451
# 10                     0.460

# %%
d120.columns = [x.strip() for x in d120.columns]

# %%
fig, ax = plt.subplots(figsize=(8,5))
d120.plot.scatter(y='F [N] ZWICK', x='F [N] Python', ax=ax)
ax.grid()

# %% [markdown]
# ### Fit a quadratic model

# %%
x=d120['F [N] Python'].values
y=d120['F [N] ZWICK'].values

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)
x_new = np.linspace(0,100,200)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x=x, 
           y=y,
           marker='o', color="r", label="data")
ax.plot(x_new, p(x_new), color="blue",
        label='Fitted Function:\n $y = %0.2fx^{2}  {%0.2f x} + %0.2f$' % (z[0],z[1],z[2]))
ax.grid()
ax.set_ylabel('F [N]/ZWICK', size=18)
ax.set_xlabel('F [N]/Python', size=18)
ax.legend(fontsize=16);

# %% [markdown]
# ## Kugeldurchmesser 6.5 [mm]

# %%
d65 = pd.read_excel('../data/empirical/Serie1_6,5_4mmKugel_13032019_Rohdaten.xlsx', skipfooter=10)
d65
# Out:
#     Kugeldurchmesser [mm]  F [N]/ZWICK  F [N]/Python  Fläche (Pixel)  \
# 0                     6.5            2          2.40              30
# 1                     NaN            5          9.42             104
# 2                     NaN           10         18.89             193
# 3                     NaN           20         30.58             296
# 4                     NaN           30         36.01             342
# 5                     NaN           40         45.30             428
# 6                     NaN           50         50.00             465
# 7                     NaN           60         54.70             505
# 8                     NaN           70         59.20             542
# 9                     NaN           80         63.00             572
# 10                    NaN          100         70.31             625
# 11                    NaN          120         76.55             680
# 12                    NaN          150         87.06             758
#
#     Farbgewicht  Gewicht/Fläche  Fläche (mm, korrigiert)  Druck [Mpa]
# 0            10           0.321                     0.03        79.49
# 1            38           0.364                     0.10        90.00
# 2            76           0.393                     0.19        97.29
# 3           123           0.415                     0.30       102.71
# 4           145           0.423                     0.34       104.68
# 5           182           0.425                     0.43       105.22
# 6           201           0.432                     0.47       106.89
# 7           220           0.435                     0.51       107.68
# 8           238           0.439                     0.55       108.58
# 9           253           0.443                     0.58       109.49
# 10          283           0.452                     0.63       111.82
# 11          308           0.453                     0.68       111.91
# 12          350           0.462                     0.76       114.17

# %%
fig, ax = plt.subplots(figsize=(8,5))
d65.plot.scatter(y='F [N]/ZWICK', x='F [N]/Python', ax=ax)
ax.grid()

# %% [markdown]
# ### Fit a quadratic model

# %%
x=d65['F [N]/Python'].values
y=d65['F [N]/ZWICK'].values

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)
x_new = np.linspace(0,100,200)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x=x, 
           y=y,
           marker='o', color="r", label="data")
ax.plot(x_new, p(x_new), color="blue",
        label='Fitted Function:\n $y = %0.2fx^{2}  {%0.2f x} + %0.2f$' % (z[0],z[1],z[2]))
ax.grid()
ax.set_ylabel('F [N]/ZWICK', size=18)
ax.set_xlabel('F [N]/Python', size=18)
ax.legend(fontsize=16);

# %% [markdown]
# ## Kugeldurchmesser 4.0 [mm]

# %%
d40 = pd.read_excel('../data/empirical/Serie1_6,5_4mmKugel_13032019_Rohdaten.xlsx', 
                    skiprows=list(range(1,15)))
d40
# Out:
#    Kugeldurchmesser [mm]  F [N]/ZWICK  F [N]/Python  Fläche (Pixel)  \
# 0                    4.0            2          3.12              29
# 1                    NaN            5         12.27             100
# 2                    NaN           10         20.69             161
# 3                    NaN           20         31.72             240
# 4                    NaN           30         38.93             287
# 5                    NaN           40         44.55             321
# 6                    NaN           50         50.00             357
# 7                    NaN           60         53.02             367
# 8                    NaN           70         57.96             403
#
#    Farbgewicht  Gewicht/Fläche  Fläche (mm, korrigiert)  Druck [Mpa]
# 0           10           0.330                     0.03       106.90
# 1           38           0.376                     0.10       121.98
# 2           63           0.394                     0.16       127.75
# 3           97           0.405                     0.24       131.39
# 4          119           0.416                     0.29       134.83
# 5          137           0.425                     0.32       137.96
# 6          153           0.429                     0.36       139.23
# 7          163           0.443                     0.37       143.61
# 8          178           0.441                     0.41       142.96

# %%
fig, ax = plt.subplots(figsize=(8,5))
d40.plot.scatter(y='F [N]/ZWICK', x='F [N]/Python', ax=ax)
ax.grid()

# %% [markdown]
# ### Fit a quadratic model

# %%
x=d40['F [N]/Python'].values
y=d40['F [N]/ZWICK'].values

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)
x_new = np.linspace(0,100,200)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x=x, 
           y=y,
           marker='o', color="r", label="data")
ax.plot(x_new, p(x_new), color="blue",
        label='Fitted Function:\n $y = %0.2fx^{2}  {%0.2f x} + %0.2f$' % (z[0],z[1],z[2]))
ax.grid()
ax.set_ylabel('F [N]/ZWICK', size=18)
ax.set_xlabel('F [N]/Python', size=18)
ax.legend(fontsize=16);

# %% [markdown]
# ## Joint plot

# %%
x_new = np.linspace(0,100,200)
fig, ax = plt.subplots(figsize=(12,6))

x=d40['F [N]/Python'].values
y=d40['F [N]/ZWICK'].values
z = np.polyfit(x, y, 2)
p40 = np.poly1d(z)

ax.scatter(x=x, 
           y=y,
           marker='o', color="green", label="data - 40 mm")

x=d65['F [N]/Python'].values
y=d65['F [N]/ZWICK'].values
z = np.polyfit(x, y, 2)
p65 = np.poly1d(z)

ax.scatter(x=x, 
           y=y,
           marker='o', color="r", label="data - 65 mm")

x=d120['F [N] Python'].values
y=d120['F [N] ZWICK'].values
z = np.polyfit(x, y, 2)
p120 = np.poly1d(z)

ax.scatter(x=x, 
           y=y,
           marker='o', color="blue", label="data - 120 mm")



ax.plot(x_new, p40(x_new), color="green",
        label='Fitted Function (40 mm)')

ax.plot(x_new, p65(x_new), color="r",
        label='Fitted Function (65 mm)')

ax.plot(x_new, p120(x_new), color="blue",
        label='Fitted Function (120 mm)')

ax.grid()
ax.set_ylabel('F [N]/ZWICK', size=18)
ax.set_xlabel('F [N]/Python', size=18)
ax.legend(fontsize=16);

# %% [markdown]
# ### Joint model

# %%
x= np.hstack([d65['F [N]/Python'].values, d40['F [N]/Python'].values, d120['F [N] Python'].values])
y= np.hstack([d65['F [N]/ZWICK'].values, d40['F [N]/ZWICK'].values, d120['F [N] ZWICK'].values])

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)
x_new = np.linspace(0,100,200)

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x=x, 
           y=y,
           marker='o', color="r", label="data")
ax.plot(x_new, p(x_new), color="blue",
        label='Fitted Function:\n $y = %0.2fx^{2}  {%0.2f x} + %0.2f$' % (z[0],z[1],z[2]))
ax.grid()
ax.set_ylabel('F [N]/ZWICK', size=18)
ax.set_xlabel('F [N]/Python', size=18)
ax.legend(fontsize=16);

# %% [markdown]
# ### Save model for further usage

# %%
import json
with open('../models/force_correction.json', 'w') as f:
    json.dump({'x_computed':x.tolist(), 'y_measured':y.tolist()}, f)

# %%
(x,y)
# Out:
# (array([ 2.4 ,  9.42, 18.89, 30.58, 36.01, 45.3 , 50.  , 54.7 , 59.2 ,
#         63.  , 70.31, 76.55, 87.06,  3.12, 12.27, 20.69, 31.72, 38.93,
#         44.55, 50.  , 53.02, 57.96,  0.11,  5.62, 16.12, 29.84, 37.71,
#         45.16, 50.  , 54.64, 61.36, 66.4 , 72.61]),
#  array([  2,   5,  10,  20,  30,  40,  50,  60,  70,  80, 100, 120, 150,
#           2,   5,  10,  20,  30,  40,  50,  60,  70,   2,   5,  10,  20,
#          30,  40,  50,  60,  70,  80, 100]))
